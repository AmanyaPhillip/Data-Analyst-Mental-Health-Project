# %%
import pandas as pd
from pathlib import Path

# Go up one level from /notebooks to repo root
ROOT = Path.cwd().parent

CLEANED = ROOT / "data" / "processed" / "02_cleaned"

df = pd.read_csv(CLEANED / "perceived_mh_annual.csv")
df.head()
# Out:
#     ref_date                        geo        dguid  \
# 0  2019/2020  Newfoundland and Labrador  2021A000210
# 1  2021/2022  Newfoundland and Labrador  2021A000210
# 2  2023/2024  Newfoundland and Labrador  2021A000210
# 3  2019/2020  Newfoundland and Labrador  2021A000210
# 4  2021/2022  Newfoundland and Labrador  2021A000210
#
#                   age_group         sex  \
# 0  Total, 18 years and over  Both sexes
# 1  Total, 18 years and over  Both sexes
# 2  Total, 18 years and over  Both sexes
# 3  Total, 18 years and over  Both sexes
# 4  Total, 18 years and over  Both sexes
#
#                                          indicator characteristic      uom  \
# 0  Perceived mental health, very good or excellent        Percent  Percent
# 1  Perceived mental health, very good or excellent        Percent  Percent
# 2  Perceived mental health, very good or excellent        Percent  Percent
# 3            Perceived mental health, fair or poor        Percent  Percent
# 4            Perceived mental health, fair or poor        Percent  Percent
#
#    uom_id scalar_factor  scalar_id       vector coordinate  value status
# 0     239         units          0  v1806947204  2.1.1.3.4   68.6    NaN
# 1     239         units          0  v1806947204  2.1.1.3.4   58.3    NaN
# 2     239         units          0  v1806947204  2.1.1.3.4   53.5    NaN
# 3     239         units          0  v1806947211  2.1.1.4.4    8.0    NaN
# 4     239         units          0  v1806947211  2.1.1.4.4   13.2    NaN

# %%
df.shape
# Out:
# (936, 15)

# %%
df.columns
# Out:
# Index(['ref_date', 'geo', 'dguid', 'age_group', 'sex', 'indicator',
#        'characteristic', 'uom', 'uom_id', 'scalar_factor', 'scalar_id',
#        'vector', 'coordinate', 'value', 'status'],
#       dtype='str')

# %%
df.dtypes
# Out:
# ref_date              str
# geo                   str
# dguid                 str
# age_group             str
# sex                   str
# indicator             str
# characteristic        str
# uom                   str
# uom_id              int64
# scalar_factor         str
# scalar_id           int64
# vector                str
# coordinate            str
# value             float64
# status                str
# dtype: object

# %%
df.sample(5)
# Out:
#       ref_date                        geo        dguid  \
# 31   2021/2022  Newfoundland and Labrador  2021A000210
# 227  2023/2024              New Brunswick  2021A000213
# 884  2023/2024                    Nunavut  2021A000262
# 274  2021/2022              New Brunswick  2021A000213
# 425  2023/2024                    Ontario  2021A000235
#
#                     age_group         sex  \
# 31   Total, 18 years and over       Males
# 227  Total, 18 years and over  Both sexes
# 884  Total, 18 years and over  Both sexes
# 274  Total, 18 years and over     Females
# 425  Total, 18 years and over     Females
#
#                                              indicator characteristic  \
# 31   Perceived life stress, most days quite a bit o...        Percent
# 227                                      Mood disorder        Percent
# 884                                     Heavy drinking        Percent
# 274                                      Mood disorder        Percent
# 425                       Cannabis use, past 12 months        Percent
#
#          uom  uom_id scalar_factor  scalar_id       vector    coordinate  \
# 31   Percent     239         units          0  v1806947393     2.1.2.5.4
# 227  Percent     239         units          0  v1806983760   15.1.1.11.4
# 884  Percent     239         units          0  v1807274721  116.1.1.19.4
# 274  Percent     239         units          0  v1806984096   15.1.3.11.4
# 425  Percent     239         units          0  v1807056394   40.1.3.15.4
#
#      value status
# 31    15.8    NaN
# 227   15.7    NaN
# 884   21.0    NaN
# 274   15.7    NaN
# 425   18.3    NaN

# %%
df.isna().sum()
# Out:
# ref_date            0
# geo                 0
# dguid               0
# age_group           0
# sex                 0
# indicator           0
# characteristic      0
# uom                 0
# uom_id              0
# scalar_factor       0
# scalar_id           0
# vector              0
# coordinate          0
# value              26
# status            898
# dtype: int64
